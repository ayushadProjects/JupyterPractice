# %%
import pandas as pd

# %%
account = {
    "student_ID": [100, 101, 201, 331],
    "first_name": ["Ayush", "Ryan", "Chisato", "Isabelle"],
    "last_name": ["Adhikari", "Griffin", "Nii", "Bui"],
    "University": ["CSU", "CSU", "CSU", "DU"],
    "Major": ["CIS", "CS", "Piano", "Nutrition"],
    "Salary": [200000, 100000, 50000, 75000],
    "Age": [21, 22, 30, 20],
    "GPA": [4.0, 4.0, 3.5, 3.8],
}

# %%
df = pd.DataFrame(account)

# %%
df
# Out:
#    student_ID first_name last_name University      Major  Salary  Age  GPA
# 0         100      Ayush  Adhikari        CSU        CIS  200000   21  4.0
# 1         101       Ryan   Griffin        CSU         CS  100000   22  4.0
# 2         201    Chisato       Nii        CSU      Piano   50000   30  3.5
# 3         331   Isabelle       Bui         DU  Nutrition   75000   20  3.8

# %%
df.tail(1)
# Out:
#    student_ID first_name last_name University      Major  Salary  Age  GPA
# 3         331   Isabelle       Bui         DU  Nutrition   75000   20  3.8

# %%
df.set_index("student_ID", inplace = True)

# %%
df["first_name"] + " " + df["last_name"]
# Out:
# student_ID
# 100    Ayush Adhikari
# 101      Ryan Griffin
# 201       Chisato Nii
# 331      Isabelle Bui
# dtype: object

# %%
df["full_name"] = df["first_name"] + " " + df["last_name"]

# %%
df
# Out:
#            first_name last_name University      Major  Salary  Age  GPA  \
# student_ID
# 100             Ayush  Adhikari        CSU        CIS  200000   21  4.0
# 101              Ryan   Griffin        CSU         CS  100000   22  4.0
# 201           Chisato       Nii        CSU      Piano   50000   30  3.5
# 331          Isabelle       Bui         DU  Nutrition   75000   20  3.8
#
#                  full_name
# student_ID
# 100         Ayush Adhikari
# 101           Ryan Griffin
# 201            Chisato Nii
# 331           Isabelle Bui

# %%
df.loc[100]
# Out:
# first_name             Ayush
# last_name           Adhikari
# University               CSU
# Major                    CIS
# Salary                200000
# Age                       21
# GPA                      4.0
# full_name     Ayush Adhikari
# Name: 100, dtype: object

# %%
df.drop(columns = ["first_name", "last_name"], inplace = True)

# %%
df
# Out:
#            University      Major  Salary  Age  GPA       full_name
# student_ID
# 100               CSU        CIS  200000   21  4.0  Ayush Adhikari
# 101               CSU         CS  100000   22  4.0    Ryan Griffin
# 201               CSU      Piano   50000   30  3.5     Chisato Nii
# 331                DU  Nutrition   75000   20  3.8    Isabelle Bui

# %%
df["full_name"].str.split(" ", expand = True)
# Out:
#                    0         1
# student_ID
# 100            Ayush  Adhikari
# 101             Ryan   Griffin
# 201          Chisato       Nii
# 331         Isabelle       Bui

# %%
df[["first_name", "last_name"]] = df["full_name"].str.split(" ", expand = True)

# %%
df
# Out:
#            University      Major  Salary  Age  GPA       full_name first_name  \
# student_ID
# 100               CSU        CIS  200000   21  4.0  Ayush Adhikari      Ayush
# 101               CSU         CS  100000   22  4.0    Ryan Griffin       Ryan
# 201               CSU      Piano   50000   30  3.5     Chisato Nii    Chisato
# 331                DU  Nutrition   75000   20  3.8    Isabelle Bui   Isabelle
#
#            last_name
# student_ID
# 100         Adhikari
# 101          Griffin
# 201              Nii
# 331              Bui

# %%
# Adding ore removing rows of data------------------------------------

# %%
df.append({"first_name": "Tony"}, ignore_index = True)
# Out:
# C:\Users\Ayush\AppData\Local\Temp\ipykernel_18048\515837835.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({"first_name": "Tony"}, ignore_index = True)
#   University      Major    Salary   Age  GPA       full_name first_name  \
# 0        CSU        CIS  200000.0  21.0  4.0  Ayush Adhikari      Ayush
# 1        CSU         CS  100000.0  22.0  4.0    Ryan Griffin       Ryan
# 2        CSU      Piano   50000.0  30.0  3.5     Chisato Nii    Chisato
# 3         DU  Nutrition   75000.0  20.0  3.8    Isabelle Bui   Isabelle
# 4        NaN        NaN       NaN   NaN  NaN             NaN       Tony
#
#   last_name
# 0  Adhikari
# 1   Griffin
# 2       Nii
# 3       Bui
# 4       NaN

# %%
accounts_2 = {
    "first_name": ["Tony", "Steve", "Iron"],
    "last_name": ["Stark", "Rogers", "Man"],
    "email_add": ["tony@email.com", "steve.yahoo.com", "iron.gmail.com"]
}

# %%
df2 = pd.DataFrame(accounts_2)

# %%
df2
# Out:
#   first_name last_name        email_add
# 0       Tony     Stark   tony@email.com
# 1      Steve    Rogers  steve.yahoo.com
# 2       Iron       Man   iron.gmail.com

# %%
df.append(df2, ignore_index = True)
# Out:
# C:\Users\Ayush\AppData\Local\Temp\ipykernel_18048\1169785372.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df2, ignore_index = True)
#   University      Major    Salary   Age  GPA       full_name first_name  \
# 0        CSU        CIS  200000.0  21.0  4.0  Ayush Adhikari      Ayush
# 1        CSU         CS  100000.0  22.0  4.0    Ryan Griffin       Ryan
# 2        CSU      Piano   50000.0  30.0  3.5     Chisato Nii    Chisato
# 3         DU  Nutrition   75000.0  20.0  3.8    Isabelle Bui   Isabelle
# 4        NaN        NaN       NaN   NaN  NaN             NaN       Tony
# 5        NaN        NaN       NaN   NaN  NaN             NaN      Steve
# 6        NaN        NaN       NaN   NaN  NaN             NaN       Iron
#
#   last_name        email_add
# 0  Adhikari              NaN
# 1   Griffin              NaN
# 2       Nii              NaN
# 3       Bui              NaN
# ...

# %%
df = df.append(df2, ignore_index = True)
# Out:
# C:\Users\Ayush\AppData\Local\Temp\ipykernel_18048\89406493.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2, ignore_index = True)

# %%
df
# Out:
#   University      Major    Salary   Age  GPA       full_name first_name  \
# 0        CSU        CIS  200000.0  21.0  4.0  Ayush Adhikari      Ayush
# 1        CSU         CS  100000.0  22.0  4.0    Ryan Griffin       Ryan
# 2        CSU      Piano   50000.0  30.0  3.5     Chisato Nii    Chisato
# 3         DU  Nutrition   75000.0  20.0  3.8    Isabelle Bui   Isabelle
# 4        NaN        NaN       NaN   NaN  NaN             NaN       Tony
# 5        NaN        NaN       NaN   NaN  NaN             NaN      Steve
# 6        NaN        NaN       NaN   NaN  NaN             NaN       Iron
#
#   last_name        email_add
# 0  Adhikari              NaN
# 1   Griffin              NaN
# 2       Nii              NaN
# 3       Bui              NaN
# 4     Stark   tony@email.com
# 5    Rogers  steve.yahoo.com
# 6       Man   iron.gmail.com

# %%
df["email_add"].fillna(df["first_name"] + "@email.com", inplace = True)

# %%
df
# Out:
#   University      Major    Salary   Age  GPA       full_name first_name  \
# 0        CSU        CIS  200000.0  21.0  4.0  Ayush Adhikari      Ayush
# 1        CSU         CS  100000.0  22.0  4.0    Ryan Griffin       Ryan
# 2        CSU      Piano   50000.0  30.0  3.5     Chisato Nii    Chisato
# 3         DU  Nutrition   75000.0  20.0  3.8    Isabelle Bui   Isabelle
# 4        NaN        NaN       NaN   NaN  NaN             NaN       Tony
# 5        NaN        NaN       NaN   NaN  NaN             NaN      Steve
# 6        NaN        NaN       NaN   NaN  NaN             NaN       Iron
#
#   last_name           email_add
# 0  Adhikari     Ayush@email.com
# 1   Griffin      Ryan@email.com
# 2       Nii   Chisato@email.com
# 3       Bui  Isabelle@email.com
# 4     Stark      tony@email.com
# 5    Rogers     steve.yahoo.com
# 6       Man      iron.gmail.com

# %%
df.loc[5]
# Out:
# University                NaN
# Major                     NaN
# Salary                    NaN
# Age                       NaN
# GPA                       NaN
# full_name                 NaN
# first_name              Steve
# last_name              Rogers
# email_add     steve.yahoo.com
# Name: 5, dtype: object

# %%
df.loc[5, "email_add"] = "steve@yahoo.com"

# %%
df.loc[6, "email_add"] = "iron@gmail.com"

# %%
df
# Out:
#   University      Major    Salary   Age  GPA       full_name first_name  \
# 0        CSU        CIS  200000.0  21.0  4.0  Ayush Adhikari      Ayush
# 1        CSU         CS  100000.0  22.0  4.0    Ryan Griffin       Ryan
# 2        CSU      Piano   50000.0  30.0  3.5     Chisato Nii    Chisato
# 3         DU  Nutrition   75000.0  20.0  3.8    Isabelle Bui   Isabelle
# 4        NaN        NaN       NaN   NaN  NaN             NaN       Tony
# 5        NaN        NaN       NaN   NaN  NaN             NaN      Steve
# 6        NaN        NaN       NaN   NaN  NaN             NaN       Iron
#
#   last_name           email_add
# 0  Adhikari     Ayush@email.com
# 1   Griffin      Ryan@email.com
# 2       Nii   Chisato@email.com
# 3       Bui  Isabelle@email.com
# 4     Stark      tony@email.com
# 5    Rogers     steve@yahoo.com
# 6       Man      iron@gmail.com

# %%
df.drop(index = 6)
# Out:
#   University      Major    Salary   Age  GPA       full_name first_name  \
# 0        CSU        CIS  200000.0  21.0  4.0  Ayush Adhikari      Ayush
# 1        CSU         CS  100000.0  22.0  4.0    Ryan Griffin       Ryan
# 2        CSU      Piano   50000.0  30.0  3.5     Chisato Nii    Chisato
# 3         DU  Nutrition   75000.0  20.0  3.8    Isabelle Bui   Isabelle
# 4        NaN        NaN       NaN   NaN  NaN             NaN       Tony
# 5        NaN        NaN       NaN   NaN  NaN             NaN      Steve
#
#   last_name           email_add
# 0  Adhikari     Ayush@email.com
# 1   Griffin      Ryan@email.com
# 2       Nii   Chisato@email.com
# 3       Bui  Isabelle@email.com
# 4     Stark      tony@email.com
# 5    Rogers     steve@yahoo.com

# %%
df.drop(columns = "email_add")
# Out:
#   University      Major    Salary   Age  GPA       full_name first_name  \
# 0        CSU        CIS  200000.0  21.0  4.0  Ayush Adhikari      Ayush
# 1        CSU         CS  100000.0  22.0  4.0    Ryan Griffin       Ryan
# 2        CSU      Piano   50000.0  30.0  3.5     Chisato Nii    Chisato
# 3         DU  Nutrition   75000.0  20.0  3.8    Isabelle Bui   Isabelle
# 4        NaN        NaN       NaN   NaN  NaN             NaN       Tony
# 5        NaN        NaN       NaN   NaN  NaN             NaN      Steve
# 6        NaN        NaN       NaN   NaN  NaN             NaN       Iron
#
#   last_name
# 0  Adhikari
# 1   Griffin
# 2       Nii
# 3       Bui
# 4     Stark
# 5    Rogers
# 6       Man

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
if df.duplicated() == True: df.drop(
